# %% [markdown]
# # Species trees

# %%
import toytree
import ipcoal

# %%
model = ipcoal.Model(Ne=1000, nsamples=5, recomb=1e-7, mut=1e-7, seed_mutations=123, 
                     seed_trees=123, store_tree_sequences=True)
model.sim_loci(2, 20000)

# %%
model.draw_genealogy(1);
# Out:
# <div class="toyplot" id="tbd41b446f78e45aebea55c6071501918" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="350.0px" height="265.0px" viewBox="0 0 350.0 265.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t67f0c220343644d095e134c8644c6203"><g class="toyplot-coordinates-Cartesian" id="t6f17994cb18d4a3c9a221e7e7746d6ef"><clipPath id="t620c4887a53c45f092a39ea645b45885"><rect x="35.0" y="35.0" width="280.0" height="195.0"></rect></clipPath><g clip-path="url(#t620c4887a53c45f092a39ea645b45885)"><g class="toytree-mark-Toytree" id="t200bfb2c68fd481986fa02c208462a94"><g class="toytree-Edges" style="fill:non
# ...

# %%
import numpy as np

# %%
model.draw_seqview(idx=0,);
# Out:
# <div class="toyplot" id="t8a9b40fe34c447c0adee5e97857f9be0" style="text-align:center;width:19300.0px"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="19300.0px" height="180.0px" viewBox="0 0 19300.0 180.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t02c98b792f534f5caae288a072fd9dbb"><g class="toyplot-coordinates-Table" id="t8ae62d6f3af440b48d2585bed6483068"><g transform="translate(75.0,57.4)"><text x="-10.008" y="3.066" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">p_0</text></g><rect x="101.5" y="50.0" widt
# ...

# %%
# model.draw_tree_sequence()

# %%
ts = toytree.utils.toytree_sequence(model.ts_dict[0], name_dict=model.tipdict)

# %%
ts.draw_tree(idx=1);
# Out:
# 0
# ...

# %%
t = model.ts_dict[0].trees()

# %%
tt = next(t)

# %%
for s in tt.sites():
    print(s.id, s.position, s.mutations)#.site, s.time)
# Out:
# 0 750.0 [Mutation(id=0, site=0, node=4, derived_state='C', parent=-1, metadata=b'', time=1962.6151508497528)]

# %%
for s in model.ts_dict[0].sites():
    print(s)
# Out:
# Site(id=0, position=750.0, ancestral_state='T', mutations=[Mutation(id=0, site=0, node=4, derived_state='C', parent=-1, metadata=b'', time=1962.6151508497528)], metadata=b'')
# Site(id=1, position=2623.0, ancestral_state='T', mutations=[Mutation(id=1, site=1, node=4, derived_state='A', parent=-1, metadata=b'', time=2774.229113823098)], metadata=b'')
# Site(id=2, position=2833.0, ancestral_state='G', mutations=[Mutation(id=2, site=2, node=1, derived_state='C', parent=-1, metadata=b'', time=147.21162214524054)], metadata=b'')
# Site(id=3, position=3544.0, ancestral_state='A', mutations=[Mutation(id=3, site=3, node=4, derived_state='G', parent=-1, metadata=b'', time=1678.2060546289483)], metadata=b'')
# Site(id=4, position=6464.0, ancestral_state='T', mutations=[Mutation(id=4, site=4, node=8, derived_state='G', parent=-1, metadata=b'', time=1564.2026367343005)], metadata=b'')
# ...

# %%
for mut in model.ts_dict[0].mutations():
    print(mut)
# Out:
# Mutation(id=0, site=0, node=4, derived_state='C', parent=-1, metadata=b'', time=1962.6151508497528)
# Mutation(id=1, site=1, node=4, derived_state='A', parent=-1, metadata=b'', time=2774.229113823098)
# Mutation(id=2, site=2, node=1, derived_state='C', parent=-1, metadata=b'', time=147.21162214524054)
# Mutation(id=3, site=3, node=4, derived_state='G', parent=-1, metadata=b'', time=1678.2060546289483)
# Mutation(id=4, site=4, node=8, derived_state='G', parent=-1, metadata=b'', time=1564.2026367343005)
# Mutation(id=5, site=5, node=4, derived_state='C', parent=-1, metadata=b'', time=1929.737322211157)
# Mutation(id=6, site=6, node=4, derived_state='A', parent=-1, metadata=b'', time=1905.919270536624)
# Mutation(id=7, site=7, node=8, derived_state='G', parent=-1, metadata=b'', time=1197.9482791384835)
# Mutation(id=8, site=8, node=1, derived_state='G', parent=-1, metadata=b'', time=18.602533105570735)
# ...

# %%
ts.draw_tree_sequence(width=800, scrollable=False, node_sizes=7, node_colors="black");
# Out:
# <div class="toyplot" id="t7eddf22b42c54c7eab51311e508582d5" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="800.0px" height="325.0px" viewBox="0 0 800.0 325.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tdbbe51046f6a4994b781fe03ca9fe8c6"><g class="toyplot-coordinates-Cartesian" id="t53c4a207661e4710977c50cb1b43df71"><clipPath id="te99b1fb5720848ff8164f9df8dcdc6b8"><rect x="30.0" y="30.0" width="740.0" height="265.0"></rect></clipPath><g clip-path="url(#te99b1fb5720848ff8164f9df8dcdc6b8)"></g><g class="toyplot-coordinates-Axis" id="ted9190ccaac24b4fac87097c41ec9976" transform="translate(50.0,275.0)
# ...

# %%
ts.draw_tree(site=1, layout='d', scale_bar=True);
# Out:
# <div class="toyplot" id="t13a898fc8b7e4d7aaf7376d0ad3a5760" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="350.0px" height="265.0px" viewBox="0 0 350.0 265.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t5bb39a7a756f426e8103b84a2e11f726"><g class="toyplot-coordinates-Cartesian" id="t33420cc4b5764dbea3639d6b943c1aa5"><clipPath id="t2df55003feb34e5ba04bf4d57ae2d908"><rect x="35.0" y="35.0" width="280.0" height="195.0"></rect></clipPath><g clip-path="url(#t2df55003feb34e5ba04bf4d57ae2d908)"><g class="toytree-mark-Toytree" id="t701f4ba60bb14c199a4d24f241ab419c"><g class="toytree-Edges" style="fill:non
# ...

# %%
t.get_parent_dict()

# %%
toytree.tree("(1,(2,(4,(0,3)5)6)7)8;").draw('p', use_edge_lengths=False);

# %%
model.tipdict

# %%
[i for i in n()]

# %%
ts0 = model.ts_dict[0]

# %%
ts0.draw_svg()

# %%
# %%SVG
#
# <svg baseProfile="full" height="200" version="1.1" width="200" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><style type="text/css"><![CDATA[.background path {fill: #808080; fill-opacity: 0}.background path:nth-child(odd) {fill-opacity: .1}.axes {font-size: 14px}.x-axis .tick .lab {font-weight: bold; dominant-baseline: hanging}.axes, .tree {font-size: 14px; text-anchor: middle}.axes line, .edge {stroke: black; fill: none}.y-axis .grid {stroke: #FAFAFA}.node > .sym {fill: black; stroke: none}.site > .sym {stroke: black}.mut text {fill: red; font-style: italic}.mut.extra text {fill: hotpink}.mut line {fill: none; stroke: none}.mut .sym {fill: none; stroke: red}.mut.extra .sym {stroke: hotpink}.node .mut .sym {stroke-width: 1.5px}.tree text, .tree-sequence text {dominant-baseline: central}.plotbox .lab.lft {text-anchor: end}.plotbox .lab.rgt {text-anchor: start}]]></style></defs><g class="tree-sequence"><g class="background"><path d="M20,0 l160,0 l0,138.2 l0,25 l0,5 l-160,0 l0,-5 l0,-25 l0,-138.2z" /></g><g class="axes"><g class="x-axis"><g transform="translate(100 200)"><text class="lab" text-anchor="middle" transform="translate(0 -11)">Genome position</text></g><line x1="20" x2="180" y1="163.2" y2="163.2" /><g class="ticks"><g class="tick" transform="translate(20 163.2)"><line x1="0" x2="0" y1="0" y2="5" /><g transform="translate(0 6)"><text class="lab">0</text></g></g><g class="tick" transform="translate(180 163.2)"><line x1="0" x2="0" y1="0" y2="5" /><g transform="translate(0 6)"><text class="lab">1</text></g></g></g><g class="site s0" transform="translate(20 163.2)"><line class="sym" x1="0" x2="0" y1="0" y2="-10" /><g class="mut m0"><polyline class="sym" points="2.5,-6.5 0,-1.5 -2.5,-6.5" /></g></g></g></g><g class="plotbox trees"><g class="tree t0" transform="translate(20 0)"><g class="plotbox"><g class="c2 node n8 p0 root" transform="translate(57.5 26.8)"><g class="a8 i1 leaf node n0 p0 sample" transform="translate(-25.5 94.6)"><path class="edge" d="M 0 0 V -94.6 H 25.5" /><rect class="sym" height="6" width="6" x="-3" y="-3" /><text class="lab" transform="translate(0 11)">0</text></g><g class="a8 c2 node n7 p0" transform="translate(25.5 29.3022)"><g class="a7 i2 leaf m0 node n1 p0 s0 sample" transform="translate(-27 65.2978)"><path class="edge" d="M 0 0 V -65.2978 H 27" /><g class="mut m0 s0" transform="translate(0 -58.5152)"><line x1="0" x2="0" y1="0" y2="58.5152" /><path class="sym" d="M -3,-3 l 6,6 M -3,3 l 6,-6" /><text class="lab lft" transform="translate(-5 0)">0</text></g><rect class="sym" height="6" width="6" x="-3" y="-3" /><text class="lab" transform="translate(0 11)">1</text></g><g class="a7 c2 node n6 p0" transform="translate(27 41.3986)"><g class="a6 i4 leaf node n4 p0 sample" transform="translate(18 23.8991)"><path class="edge" d="M 0 0 V -23.8991 H -18" /><rect class="sym" height="6" width="6" x="-3" y="-3" /><text class="lab" transform="translate(0 11)">4</text></g><g class="a6 c2 node n5 p0" transform="translate(-18 15.1542)"><g class="a5 i0 leaf node n2 p0 sample" transform="translate(-12 8.74493)"><path class="edge" d="M 0 0 V -8.74493 H 12" /><rect class="sym" height="6" width="6" x="-3" y="-3" /><text class="lab" transform="translate(0 11)">2</text></g><g class="a5 i3 leaf node n3 p0 sample" transform="translate(12 8.74493)"><path class="edge" d="M 0 0 V -8.74493 H -12" /><rect class="sym" height="6" width="6" x="-3" y="-3" /><text class="lab" transform="translate(0 11)">3</text></g><path class="edge" d="M 0 0 V -15.1542 H 18" /><circle class="sym" cx="0" cy="0" r="3" /><text class="lab lft" transform="translate(-3 -7.0)">5</text></g><path class="edge" d="M 0 0 V -41.3986 H -27" /><circle class="sym" cx="0" cy="0" r="3" /><text class="lab rgt" transform="translate(3 -7.0)">6</text></g><path class="edge" d="M 0 0 V -29.3022 H -25.5" /><circle class="sym" cx="0" cy="0" r="3" /><text class="lab rgt" transform="translate(3 -7.0)">7</text></g><circle class="sym" cx="0" cy="0" r="3" /><text class="lab" transform="translate(0 -11)">8</text></g></g></g></g></g></svg>
